# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Breast_cancer_diagnosis.csv')

# %%
df.columns
# Out:
# Index(['Mean Radius', 'Mean Texture', 'Mean Perimeter', 'Mean Area',
#        'Mean Smoothness', 'Mean Compactness', 'Mean Concavity',
#        'Mean Concave points', 'Mean Symmetry', 'Mean Fractal dimension',
#        'Radius Std.Error', 'Texture Std.Error', 'Perimeter Std.Error',
#        'Area Std.Error', 'Smoothness Std.Error', 'Compactness Std.Error',
#        'Concavity Std.Error', 'Concave points Std.Error', 'Symmetry Std.Error',
#        'Fractal dimension Std.Error', 'Worst Radius', 'Worst Texture',
#        'Worst Perimeter', 'Worst Area', 'Worst Smoothness',
#        'Worst Compactness', 'Worst Concavity', 'Worst Concave points',
#        'Worst Symmetry', 'Worst Fractal dimension', 'Diagnosis'],
#       dtype='object')

# %%
df.head()
# Out:
#    Mean Radius  Mean Texture  Mean Perimeter  Mean Area  Mean Smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    Mean Compactness  Mean Concavity  Mean Concave points  Mean Symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    Mean Fractal dimension  ...  Worst Texture  Worst Perimeter  Worst Area  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Mean Radius                  569 non-null    float64
#  1   Mean Texture                 569 non-null    float64
#  2   Mean Perimeter               569 non-null    float64
#  3   Mean Area                    569 non-null    float64
#  4   Mean Smoothness              569 non-null    float64
#  5   Mean Compactness             569 non-null    float64
#  6   Mean Concavity               569 non-null    float64
#  7   Mean Concave points          569 non-null    float64
#  8   Mean Symmetry                569 non-null    float64
#  9   Mean Fractal dimension       569 non-null    float64
#  10  Radius Std.Error             569 non-null    float64
#  11  Texture Std.Error            569 non-null    float64
# ...

# %%
df.describe()
# Out:
#        Mean Radius  Mean Texture  Mean Perimeter    Mean Area  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        Mean Smoothness  Mean Compactness  Mean Concavity  Mean Concave points  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# ...

# %%
print(df.isnull().sum())
# Out:
# Mean Radius                    0
# Mean Texture                   0
# Mean Perimeter                 0
# Mean Area                      0
# Mean Smoothness                0
# Mean Compactness               0
# Mean Concavity                 0
# Mean Concave points            0
# Mean Symmetry                  0
# Mean Fractal dimension         0
# Radius Std.Error               0
# Texture Std.Error              0
# Perimeter Std.Error            0
# Area Std.Error                 0
# Smoothness Std.Error           0
# Compactness Std.Error          0
# Concavity Std.Error            0
# Concave points Std.Error       0
# Symmetry Std.Error             0
# Fractal dimension Std.Error    0
# Worst Radius                   0
# Worst Texture                  0
# Worst Perimeter                0
# Worst Area                     0
# Worst Smoothness               0
# Worst Compactness              0
# Worst Concavity                0
# Worst Concave points           0
# ...

# %%
df.dropna()
# Out:
#      Mean Radius  Mean Texture  Mean Perimeter  Mean Area  Mean Smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
select_collumns_Radius = df[["Mean Radius", "Radius Std.Error", "Worst Radius", "Diagnosis"]]
select_collumns_Radius
# Out:
#      Mean Radius  Radius Std.Error  Worst Radius Diagnosis
# 0          17.99            1.0950        25.380    Malign
# 1          20.57            0.5435        24.990    Malign
# 2          19.69            0.7456        23.570    Malign
# 3          11.42            0.4956        14.910    Malign
# 4          20.29            0.7572        22.540    Malign
# ..           ...               ...           ...       ...
# 564        21.56            1.1760        25.450    Malign
# 565        20.13            0.7655        23.690    Malign
# 566        16.60            0.4564        18.980    Malign
# 567        20.60            0.7260        25.740    Malign
# 568         7.76            0.3857         9.456    Benign
#
# [569 rows x 4 columns]

# %%
# Настройка стиля графиков
sns.set(style="whitegrid")

# Построение гистограмм для распределения 'Mean Radius', 'Radius Std.Error' и 'Worst Radius'
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
sns.histplot(data=df, x='Mean Radius', kde=True, hue='Diagnosis', element="step", stat="density", common_norm=False)
plt.title('Распределение Mean Radius')

plt.subplot(1, 3, 2)
sns.histplot(data=df, x='Radius Std.Error', kde=True, hue='Diagnosis', element="step", stat="density", common_norm=False)
plt.title('Распределение Radius Std.Error')

plt.subplot(1, 3, 3)
sns.histplot(data=df, x='Worst Radius', kde=True, hue='Diagnosis', element="step", stat="density", common_norm=False)
plt.title('Распределение Worst Radius')

plt.tight_layout()
plt.show()

# %%
# Построение boxplot для параметров 'Mean Radius', 'Radius Error' и 'Worst Radius'
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
sns.boxplot(data=df, x='Diagnosis', y='Mean Radius')
plt.title('Boxplot для Mean Radius')

plt.subplot(1, 3, 2)
sns.boxplot(data=df, x='Diagnosis', y='Radius Std.Error')
plt.title('Boxplot для Radius Std.Error')

plt.subplot(1, 3, 3)
sns.boxplot(data=df, x='Diagnosis', y='Worst Radius')
plt.title('Boxplot для Worst Radius')

plt.tight_layout()
plt.show()

# %%
# Выбор интересующих столбцов для парной диаграммы
selected_columns = ['Mean Radius', 'Radius Std.Error', 'Worst Radius', 'Diagnosis']

# Создание парной диаграммы
sns.pairplot(df[selected_columns], hue='Diagnosis', markers=["o", "s"])
plt.suptitle('Парные диаграммы для выбранных параметров', y=1.02)
plt.show()

# %%
newDf = df
newDf['Diagnosis'] = df['Diagnosis'].replace({'Benign': 0, 'Malignant': 1})
# Вычисление корреляционной матрицы
corr_matrix = newDf[['Mean Radius','Radius Std.Error','Worst Radius',"Mean Texture","Texture Std.Error","Worst Texture",
                     "Mean Perimeter","Perimeter Std.Error","Worst Perimeter","Mean Area","Area Std.Error","Worst Area"]].corr()

# Визуализация корреляционной матрицы
plt.figure(figsize=(12, 10))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap='coolwarm',square=True)
plt.title('Корреляционная матрица радиуса')
plt.show()

# %%
# Сводка среднего значения и стандартного отклонения параметров для злокачественных и доброкачественных опухолей
summary = df.groupby('Diagnosis').agg(['mean', 'std']).T
print(summary)
# Out:
# Diagnosis                             Benign       Malign
# Mean Radius                 mean   12.146524    17.462830
#                             std     1.780512     3.203971
# Mean Texture                mean   17.914762    21.604906
#                             std     3.995125     3.779470
# Mean Perimeter              mean   78.075406   115.365377
#                             std    11.807438    21.854653
# Mean Area                   mean  462.790196   978.376415
#                             std   134.287118   367.937978
# Mean Smoothness             mean    0.092478     0.102898
#                             std     0.013446     0.012608
# Mean Compactness            mean    0.080085     0.145188
#                             std     0.033750     0.053987
# Mean Concavity              mean    0.046058     0.160775
#                             std     0.043442     0.075019
# Mean Concave points         mean    0.025717     0.087990
# ...
